# %% [markdown]
# # 🧪 Patient Data Analysis - EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
basic = pd.read_excel('basic_information.xlsx')
followup = pd.read_excel('followup_data.xlsx')
delivery = pd.read_excel('delivery_information.xlsx')

# %%
# Describe basic info
basic.describe()

# %%
# Visualize age distribution by gender
sns.boxplot(x='gender', y='age', data=basic)
plt.title('Age Distribution by Gender')
plt.show()
